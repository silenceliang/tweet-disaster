# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import pandas as pd
sample_submission = pd.read_csv("../input/nlp-getting-started/sample_submission.csv")
test = pd.read_csv("../input/nlp-getting-started/test.csv")
train = pd.read_csv("../input/nlp-getting-started/train.csv")

# %%
train.head(3)
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
#
#    target
# 0       1
# 1       1
# 2       1

# %%
test.head(3)
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...

# %% [markdown]
# ## Inspect The Dataset

# %% [markdown]
# ### peek the distribution of targets from our training data
# - Ensure not exists **inbalance data problem**
# - 因為是 binary classification problem，只需要檢查 `0、1` 的分布。
# - 結果證明 :
#     - disaster : `57%`
#     - non-disaster : `42%`

# %%
train['target'].value_counts().apply(lambda x: x / train['target'].count())
# Out:
# 0    0.57034
# 1    0.42966
# Name: target, dtype: float64

# %% [markdown]
# ### peek the correlation matrix to consider which feature suppose to  be important

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
corr = train[['id', 'keyword', 'location', 'target']].corr()
sns.heatmap(corr, annot=True)

# %% [markdown]
# * `id、keyword、location` 對於 `target` 的影響力普遍不高。
# * `location` 對於 `target` 的影響力最小。
#
# > 因此我們試著從 `text` 找出關聯性。

# %% [markdown]
# ## Using Word2vec As Word Representation

# %%
import gensim
word2vec_bin = "../input/nlpword2vecembeddingspretrained/GoogleNews-vectors-negative300.bin"
# Out:
# C:\Anaconda3\lib\site-packages\gensim\utils.py:865: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Using TensorFlow backend.

# %% [markdown]
# ### load word embedding generated from word2vec

# %%
def load_w2v(path):
    try:
        model = gensim.models.KeyedVectors.load_word2vec_format(path, binary=True)
        return model
    except:
        assert('fail to load word2vec file with gensim.')
    return None

# %%
vocabulary = load_w2v(word2vec_bin)

# %% [markdown]
# ### peek length of text sequence

# %% [markdown]
# #### find maximum and minimum
#
# - 取得文章長度的範圍，其目的是:
#     - 將 outlier 的資料去除。
#     - 方便定義 `np.array` 的最大長度。

# %%
sequence_length = list(map(lambda x: len(x), train['text']))
min(sequence_length), max(sequence_length)
# Out:
# (7, 157)

# %% [markdown]
# #### show the distribution of text length

# %%
sns.distplot(sequence_length, hist=True, kde=False, 
             bins=10, color = 'blue',
             hist_kws={'edgecolor':'black'})
plt.title('Histogram of sequence length')
plt.xlabel('number of words')
plt.ylabel('frequency')

# %%
assert train['id'].size == train['id'].count() == train['id'].nunique()

# %% [markdown]
# Note : `count()` 含有null的筆數，`size` 不包含null的筆數。

# %% [markdown]
# ### Convert text to document representation
# 1. 若一則text有 128 個字，dimension of word representatoion is 300-d，則 document representation 為平均所有 128 words 之 300-d 的向量。

# %% [markdown]
# #### average from all word vectors

# %%
train_content_w2v = [np.mean(np.stack([vocabulary[word.lower()] if word.lower() in vocabulary else np.zeros(300) for word in sequence], axis=0),axis=0) for sequence in  train['text']]

# %% [markdown]
# `train_content_w2v` 保存所有文章的字向量平均值當成document representation 。

# %%
assert train['text'].size == train['text'].count() == len(train_content_w2v)

# %% [markdown]
# ## Using SVM

# %%
from sklearn import svm
from sklearn.manifold import Isomap 
from sklearn.metrics import classification_report

# %% [markdown]
# ### visualization function

# %%
def visualization(x, y, pred_y):
    X_iso = Isomap(n_neighbors=10).fit_transform(x)
    fig, ax = plt.subplots(1, 2, figsize=(8, 4))
    fig.subplots_adjust(top=0.85)

    ax[0].scatter(X_iso[:, 0], X_iso[:, 1], c=pred_y)
    ax[0].set_title('Predicted labels')
    ax[1].scatter(X_iso[:, 0], X_iso[:, 1], c=y)
    ax[1].set_title('Actual Labels')
    fig.suptitle('Predicted versus actual labels', fontsize=14, fontweight='bold')
    plt.show()

# %%
def confusion_visualization(y, pred_y):
    confusion_matrix = pd.crosstab(y, pred_y,rownames=['Actual'], colnames=['Predicted'], margins=True)
    sns.heatmap(confusion_matrix, annot=True)
    print(classification_report(y, pred_y))

# %% [markdown]
# ### SVM function

# %%
def svm_model(x, y):
    clf = svm.SVC()
    clf.fit(x, y)
    pred_results = clf.predict(x)
    return pred_results

# %% [markdown]
# ### only feed text as input to SVM

# %%
train_X_only_text = train_content_w2v
train_Y = train['target']
predicted_only_text = svm_model(train_X_only_text, train_Y)

# %%
visualization(train_X_only_text, train_Y, predicted_only_text)

# %%
confusion_matrix = pd.crosstab(train_Y, predicted_only_text,rownames=['Actual'], colnames=['Predicted'],margins = True)
sns.heatmap(confusion_matrix, annot=True)
print(classification_report(train_Y, predicted_only_text))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.57      1.00      0.73      4342
#           1       0.00      0.00      0.00      3271
#
# avg / total       0.33      0.57      0.41      7613
# C:\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## Enhance with additonal features

# %% [markdown]
# 1. preprocessing keyword、location
# 2. considering `Id`、`keyword`、`location`
# 3. considering `keyword`、`location`
# 4. considering `keyword` only
# 5. considering `location` only

# %% [markdown]
# preprocessing keyword、location

# %%
train['keyword'].nunique(),train['location'].nunique()
# Out:
# (221, 3341)

# %% [markdown]
# 將 nan 轉成 0

# %%
train.fillna(0, inplace=True)

# %% [markdown]
# 將 keyword、location 離散化
# * 出現的次數越多，值越大。

# %%
unique_keys, unique_locations = train['keyword'].value_counts(), train['location'].value_counts()
train['keyword'] = train['keyword'].apply(lambda x: unique_keys[x])
train['location'] = train['location'].apply(lambda x: unique_locations[x])

# %%
doc_reps = pd.DataFrame(np.column_stack(list(zip(*train_content_w2v))), columns=list(range(300)))
train_X = pd.concat([train[['id','keyword','location']], doc_reps.reindex(train.index)], axis=1)
train_Y = train['target']
clf = svm.SVC()
clf.fit(train_X, train_Y)
predicted = clf.predict(train_X)

# %%
visualization(train_X, train_Y, predicted)

# %%
confusion_matrix = pd.crosstab(train_Y, predicted, rownames=['Actual'], colnames=['Predicted'],margins = True)
sns.heatmap(confusion_matrix, annot=True)
print(classification_report(train_Y, predicted))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.79      0.86      0.82      4342
#           1       0.79      0.70      0.74      3271
#
# avg / total       0.79      0.79      0.79      7613

# %% [markdown]
# ### 這裡判斷是 Id 造成的降維不均，將 Id 去除

# %%
train_X_without_id = train_X.drop(['id'],axis=1)

# %%
clf_without_id = svm.SVC()
clf_without_id.fit(train_X_without_id, train_Y)
predicted_without_id = clf_without_id.predict(train_X_without_id)

# %%
visualization(train_X_without_id, train_Y, predicted_without_id)

# %%
confusion_matrix = pd.crosstab(train_Y, predicted_without_id, rownames=['Actual'], colnames=['Predicted'],margins = True)
sns.heatmap(confusion_matrix, annot=True)
print(classification_report(train_Y, predicted_without_id))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.58      0.97      0.73      4342
#           1       0.64      0.07      0.13      3271
#
# avg / total       0.60      0.58      0.47      7613

# %% [markdown]
# ### 將 Id, location 去除

# %%
train_X_without_id_location = train_X.drop(['id','location'],axis=1)

# %%
clf_without_id_location = svm.SVC()
clf_without_id_location.fit(train_X_without_id_location, train_Y)
predicted_without_id_location = clf_without_id_location.predict(train_X_without_id_location)

# %%
visualization(train_X_without_id_location, train_Y, predicted_without_id_location)

# %%
confusion_matrix = pd.crosstab(train_Y, predicted_without_id_location, rownames=['Actual'], colnames=['Predicted'], margins = True)
sns.heatmap(confusion_matrix, annot=True)
print(classification_report(train_Y, predicted_without_id_location))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.57      1.00      0.73      4342
#           1       0.69      0.01      0.03      3271
#
# avg / total       0.62      0.57      0.43      7613

# %% [markdown]
# ### 將 Id, keyword 去除

# %%
train_X_without_id_keyword = train_X.drop(['id','keyword'],axis=1)

# %%
clf_without_id_keyword = svm.SVC()
clf_without_id_keyword.fit(train_X_without_id_keyword, train_Y)
predicted_without_id_keyword = clf_without_id_keyword.predict(train_X_without_id_keyword)

# %%
visualization(train_X_without_id_keyword, train_Y, predicted_without_id_keyword)

# %%
confusion_matrix = pd.crosstab(train_Y, predicted_without_id_keyword, rownames=['Actual'], colnames=['Predicted'],margins = True)
sns.heatmap(confusion_matrix, annot=True)
print(classification_report(train_Y, predicted_without_id_keyword))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.58      0.97      0.73      4342
#           1       0.62      0.06      0.11      3271
#
# avg / total       0.59      0.58      0.46      7613

# %% [markdown]
# ### 去除 stop words

# %%
from nltk.corpus import stopwords
# You will have to download the set of stop words the first time
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\x2265\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
# Load stop words
stop_words = stopwords.words('english')
stop_words = set(stop_words)

# %%
train_content_w2v_filter = [np.mean(np.stack([vocabulary[word.lower()] if word.lower() in vocabulary else np.zeros(300) for word in sequence if word.lower() not in stop_words], axis=0),axis=0) for sequence in  train['text']]

# %%
train_X_only_text = train_content_w2v_filter
train_Y = train['target']
clf_only_text = svm.SVC()
clf_only_text.fit(train_X_only_text, train_Y)
predicted_only_text = clf_only_text.predict(train_X_only_text)

# %%
visualization(train_X_only_text, train_Y, predicted_only_text)

# %%
confusion_matrix = pd.crosstab(train_Y, predicted_only_text,rownames=['Actual'], colnames=['Predicted'],margins = True)
sns.heatmap(confusion_matrix, annot=True)
print(classification_report(train_Y, predicted_only_text))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.57      1.00      0.73      4342
#           1       0.00      0.00      0.00      3271
#
# avg / total       0.33      0.57      0.41      7613
# C:\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 去除keyword為null以及location皆為null的資料

# %%
train_X_filter_all_zeros = train_X.loc[~(train==0).all(axis=1)]

# %%
train_X_without_id = train_X.drop(['id'],axis=1)

# %%
clf_without_id = svm.SVC()
clf_without_id.fit(train_X_without_id, train_Y)
predicted_without_id = clf_without_id.predict(train_X_without_id)

# %%
visualization(train_X_without_id, train_Y, predicted_without_id)

# %%
confusion_matrix = pd.crosstab(train_Y, predicted_without_id,rownames=['Actual'], colnames=['Predicted'],margins = True)
sns.heatmap(confusion_matrix, annot=True)
print(classification_report(train_Y, predicted_without_id))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.58      0.97      0.73      4342
#           1       0.64      0.07      0.13      3271
#
# avg / total       0.60      0.58      0.47      7613

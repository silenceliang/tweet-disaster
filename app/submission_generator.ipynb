# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
sample_submission = pd.read_csv("../input/nlp-getting-started/sample_submission.csv")
test_df = pd.read_csv("../input/nlp-getting-started/test.csv")
gt_df = pd.read_csv("../input/source-datasets/socialmedia-disaster-tweets-DFE.csv",error_bad_lines=False)
# Out:
# b'Skipping line 3058: expected 13 fields, saw 15\nSkipping line 8917: expected 13 fields, saw 16\n'

# %%
gt_df['choose_one'].unique()
# Out:
# array(['Relevant', 'Not Relevant', "Can't Decide"], dtype=object)

# %%
gt_df = gt_df[['choose_one', 'text']]
gt_df['target'] = (gt_df['choose_one']=='Relevant').astype(int)
gt_df['id'] = gt_df.index
gt_df
# Out:
#          choose_one                                               text  \
# 0          Relevant                 Just happened a terrible car crash
# 1          Relevant  Our Deeds are the Reason of this #earthquake M...
# 2          Relevant  Heard about #earthquake is different cities, s...
# 3          Relevant  there is a forest fire at spot pond, geese are...
# 4          Relevant             Forest fire near La Ronge Sask. Canada
# 5          Relevant  All residents asked to 'shelter in place' are ...
# 6          Relevant  13,000 people receive #wildfires evacuation or...
# 7          Relevant  Just got sent this photo from Ruby #Alaska as ...
# 8          Relevant  #RockyFire Update => California Hwy. 20 closed...
# 9          Relevant           Apocalypse lighting. #Spokane #wildfires
# 10         Relevant  #flood #disaster Heavy rain causes flash flood...
# 11         Relevant      Typhoon Soudelor kills 28 in China and Taiwan
# 12         Relevant                 We're shaking...It's an earthquake
# 13         Relevant  I'm on top of the hill and I can see a fire in...
# 14         Relevant  There's an emergency evacuation happening now ...
# 15         Relevant  I'm afraid that the tornado is coming to our a...
# 16         Relevant        Three people died from the heat wave so far
# 17         Relevant  Haha South Tampa is getting flooded hah- WAIT ...
# 18         Relevant  #raining #flooding #Florida #TampaBay #Tampa 1...
# 19         Relevant            #Flood in Bago Myanmar #We arrived Bago
# 20         Relevant  Damage to school bus on 80 in multi car crash ...
# 21     Not Relevant  They'd probably still show more life than Arse...
# 22     Not Relevant                                  Hey! How are you?
# 23     Not Relevant                                     What's up man?
# 24     Not Relevant                                      I love fruits
# 25     Not Relevant                                   Summer is lovely
# 26     Not Relevant                                  My car is so fast
# 27     Not Relevant                                   What a nice hat?
# 28     Not Relevant                       What a goooooooaaaaaal!!!!!!
# 29     Not Relevant                                          Fuck off!
# ...             ...                                                ...
# 10842      Relevant  Heat wave warning aa? Ayyo dei. Just when I pl...
# 10843      Relevant  An IS group suicide bomber detonated an explos...
# 10844  Not Relevant  I just heard a really loud bang and everyone i...
# 10845      Relevant  A gas thing just exploded and I heard screams ...
# 10846      Relevant  NWS: Flash Flood Warning Continued for Shelby ...
# 10847      Relevant  RT @LivingSafely: #NWS issues Severe #Thunders...
# 10848      Relevant  #??? #?? #??? #??? MH370: Aircraft debris foun...
# 10849      Relevant  Father-of-three Lost Control of Car After Over...
# 10850      Relevant  1.3 #Earthquake in 9Km Ssw Of Anza California ...
# 10851      Relevant  Evacuation order lifted for town of Roosevelt:...
# 10852      Relevant  See the 16yr old PKK suicide bomber who detona...
# 10853      Relevant  To conference attendees! The blue line from th...
# 10854      Relevant  The death toll in a #IS-suicide car bombing on...
# 10855      Relevant  #breaking #LA Refugio oil spill may have been ...
# 10856      Relevant  a siren just went off and it wasn't the Forney...
# 10857  Not Relevant  EARTHQUAKE SAFETY LOS ANGELES ?SAFETY FASTENE...
# 10858      Relevant  Officials say a quarantine is in place at an A...
# 10859      Relevant  #WorldNews Fallen powerlines on G:link tram: U...
# 10860      Relevant  on the flip side I'm at Walmart and there is a...
# 10861      Relevant  Storm in RI worse than last hurricane. My city...
# 10862      Relevant  Suicide bomber kills 15 in Saudi security site...
# 10863      Relevant  #stormchase Violent Record Breaking EF-5 El Re...
# 10864      Relevant  Green Line derailment in Chicago http://t.co/U...
# 10865      Relevant  Two giant cranes holding a bridge collapse int...
# 10866      Relevant  @aria_ahrary @TheTawniest The out of control w...
# 10867      Relevant  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...
# 10868      Relevant  Police investigating after an e-bike collided ...
# 10869      Relevant  The Latest: More Homes Razed by Northern Calif...
# 10870      Relevant  MEG issues Hazardous Weather Outlook (HWO) htt...
# 10871      Relevant  #CityofCalgary has activated its Municipal Eme...
#
#        target     id
# 0           1      0
# 1           1      1
# 2           1      2
# 3           1      3
# 4           1      4
# 5           1      5
# 6           1      6
# 7           1      7
# 8           1      8
# 9           1      9
# 10          1     10
# 11          1     11
# 12          1     12
# 13          1     13
# 14          1     14
# 15          1     15
# 16          1     16
# 17          1     17
# 18          1     18
# 19          1     19
# 20          1     20
# 21          0     21
# 22          0     22
# 23          0     23
# 24          0     24
# 25          0     25
# 26          0     26
# 27          0     27
# 28          0     28
# 29          0     29
# ...       ...    ...
# 10842       1  10842
# 10843       1  10843
# 10844       0  10844
# 10845       1  10845
# 10846       1  10846
# 10847       1  10847
# 10848       1  10848
# 10849       1  10849
# 10850       1  10850
# 10851       1  10851
# 10852       1  10852
# 10853       1  10853
# 10854       1  10854
# 10855       1  10855
# 10856       1  10856
# 10857       0  10857
# 10858       1  10858
# 10859       1  10859
# 10860       1  10860
# 10861       1  10861
# 10862       1  10862
# 10863       1  10863
# 10864       1  10864
# 10865       1  10865
# 10866       1  10866
# 10867       1  10867
# 10868       1  10868
# 10869       1  10869
# 10870       1  10870
# 10871       1  10871
#
# [10872 rows x 4 columns]

# %%
merged_df = pd.merge(test_df, gt_df, on='id')
merged_df
# Out:
#          id   keyword                          location  \
# 0         0       NaN                               NaN
# 1         2       NaN                               NaN
# 2         3       NaN                               NaN
# 3         9       NaN                               NaN
# 4        11       NaN                               NaN
# 5        12       NaN                               NaN
# 6        21       NaN                               NaN
# 7        22       NaN                               NaN
# 8        27       NaN                               NaN
# 9        29       NaN                               NaN
# 10       30       NaN                               NaN
# 11       35       NaN                               NaN
# 12       42       NaN                               NaN
# 13       43       NaN                               NaN
# 14       45       NaN                               NaN
# 15       46    ablaze                            London
# 16       47    ablaze    Niall's place | SAF 12 SQUAD |
# 17       51    ablaze                           NIGERIA
# 18       58    ablaze                    Live On Webcam
# 19       60    ablaze          Los Angeles, Califnordia
# 20       69    ablaze                    threeonefive.
# 21       70    ablaze                  Washington State
# 22       72    ablaze                Whoop Ass, Georgia
# 23       75    ablaze                             India
# 24       84    ablaze                               NaN
# 25       87    ablaze              scarborough, ontario
# 26       88    ablaze                               NaN
# 27       90    ablaze      121 N La Salle St, Suite 500
# 28       94    ablaze                         Wandering
# 29       99  accident                      Homewood, PA
# ...     ...       ...                               ...
# 3231  10740  wreckage               Mumbai, Maharashtra
# 3232  10742  wreckage                               NaN
# 3233  10756  wreckage                            Mumbai
# 3234  10757  wreckage                               NaN
# 3235  10758  wreckage                             India
# 3236  10761  wreckage                            Mumbai
# 3237  10762  wreckage                            Canada
# 3238  10773  wreckage                               NaN
# 3239  10778  wreckage                            Mumbai
# 3240  10781  wreckage                        our galaxy
# 3241  10791   wrecked         Sunny Southern California
# 3242  10792   wrecked                 Plymouth, England
# 3243  10796   wrecked      Deep in the heart of LibLand
# 3244  10797   wrecked                               NaN
# 3245  10801   wrecked                    Canada,Ontario
# 3246  10804   wrecked                        Love Reiss
# 3247  10806   wrecked                Seattle Washington
# 3248  10807   wrecked  Acey mountain islanddåÇTorontoåÈ
# 3249  10816   wrecked                       los angeles
# 3250  10820   wrecked                 Brussels, Belgium
# 3251  10828   wrecked                               NaN
# 3252  10836       NaN                               NaN
# 3253  10838       NaN                               NaN
# 3254  10845       NaN                               NaN
# 3255  10856       NaN                               NaN
# 3256  10857       NaN                               NaN
# 3257  10858       NaN                               NaN
# 3258  10861       NaN                               NaN
# 3259  10865       NaN                               NaN
# 3260  10868       NaN                               NaN
#
#                                                  text_x    choose_one  \
# 0                    Just happened a terrible car crash      Relevant
# 1     Heard about #earthquake is different cities, s...      Relevant
# 2     there is a forest fire at spot pond, geese are...      Relevant
# 3              Apocalypse lighting. #Spokane #wildfires      Relevant
# 4         Typhoon Soudelor kills 28 in China and Taiwan      Relevant
# 5                    We're shaking...It's an earthquake      Relevant
# 6     They'd probably still show more life than Arse...  Not Relevant
# 7                                     Hey! How are you?  Not Relevant
# 8                                      What a nice hat?  Not Relevant
# 9                                             Fuck off!  Not Relevant
# 10                                No I don't like cold!  Not Relevant
# 11                           NOOOOOOOOO! Don't do that!  Not Relevant
# 12                               No don't tell me that!  Not Relevant
# 13                                            What if?!  Not Relevant
# 14                                             Awesome!  Not Relevant
# 15    Birmingham Wholesale Market is ablaze BBC News...      Relevant
# 16    @sunkxssedharry will you wear shorts for race ...  Not Relevant
# 17    #PreviouslyOnDoyinTv: Toke MakinwaÛªs marriag...  Not Relevant
# 18    Check these out: http://t.co/rOI2NSmEJJ http:/...  Not Relevant
# 19    PSA: IÛªm splitting my personalities.\n\n?? t...  Not Relevant
# 20         beware world ablaze sierra leone &amp; guap.  Not Relevant
# 21    Burning Man Ablaze! by Turban Diva http://t.co...  Not Relevant
# 22    Not a diss song. People will take 1 thing and ...  Not Relevant
# 23    Rape victim dies as she sets herself ablaze: A...      Relevant
# 24         SETTING MYSELF ABLAZE http://t.co/6vMe7P5XhC  Not Relevant
# 25    @CTVToronto the bins in front of the field by ...  Not Relevant
# 26    #nowplaying Alfons - Ablaze 2015 on Puls Radio...  Not Relevant
# 27    'Burning Rahm': Let's hope City Hall builds a ...  Not Relevant
# 28    @PhilippaEilhart @DhuBlath hurt but her eyes a...  Not Relevant
# 29    Accident cleared in #PaTurnpike on PATP EB bet...      Relevant
# ...                                                 ...           ...
# 3231  Wreckage 'Conclusively Confirmed' as From MH37...      Relevant
# 3232  Wreckage 'conclusively confirmed' as from MH37...      Relevant
# 3233  Wreckage 'Conclusively Confirmed' as From MH37...      Relevant
# 3234  #science Now that a piece of wreckage from fli...      Relevant
# 3235  Wreckage 'Conclusively Confirmed' as From MH37...      Relevant
# 3236  Wreckage 'Conclusively Confirmed' as From MH37...      Relevant
# 3237  TOP STORY: wreckage from #MH370 officially con...      Relevant
# 3238  Wreckage 'Conclusively Confirmed' as From MH37...      Relevant
# 3239  Wreckage 'Conclusively Confirmed' as From MH37...      Relevant
# 3240  RT @australian Debris found on an Indian Ocean...  Not Relevant
# 3241  Cramer: Iger's 3 words that wrecked Disney's s...      Relevant
# 3242  Almost *wrecked* my van the other day because ...  Not Relevant
# 3243  'What manner of human being would parcel out a...  Not Relevant
# 3244  @Nathan26_RFC thought you said Saturday night ...  Not Relevant
# 3245  I just wanna ease your mind and make you feel ...  Not Relevant
# 3246  @yakubOObs think he deactivated because his no...      Relevant
# 3247  RT CNBC '3 words from Disney CEO Bob Iger wrec...  Not Relevant
# 3248  Smackdown tyme this should put me in a good mo...  Not Relevant
# 3249  @thrillhho jsyk I haven't stopped thinking abt...  Not Relevant
# 3250  @stighefootball Begovic has been garbage. He g...  Not Relevant
# 3251                 Wrecked today got my hattrick ????  Not Relevant
# 3252  #Ebola #EbolaOutbreak Ebola Virus: Birmingham ...      Relevant
# 3253  Malaysian PM confirms debris is from missing f...      Relevant
# 3254  Officials: Alabama home quarantined over possi...      Relevant
# 3255  See the 16yr old PKK suicide bomber who detona...      Relevant
# 3256  To conference attendees! The blue line from th...  Not Relevant
# 3257  The death toll in a #IS-suicide car bombing on...      Relevant
# 3258  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTE...      Relevant
# 3259  Storm in RI worse than last hurricane. My city...      Relevant
# 3260  Green Line derailment in Chicago http://t.co/U...      Relevant
#
#                                                  text_y  target
# 0                    Just happened a terrible car crash       1
# 1     Heard about #earthquake is different cities, s...       1
# 2     there is a forest fire at spot pond, geese are...       1
# 3              Apocalypse lighting. #Spokane #wildfires       1
# 4         Typhoon Soudelor kills 28 in China and Taiwan       1
# 5                    We're shaking...It's an earthquake       1
# 6     They'd probably still show more life than Arse...       0
# 7                                     Hey! How are you?       0
# 8                                      What a nice hat?       0
# 9                                             Fuck off!       0
# 10                                No I don't like cold!       0
# 11                           NOOOOOOOOO! Don't do that!       0
# 12                               No don't tell me that!       0
# 13                                            What if?!       0
# 14                                             Awesome!       0
# 15    Birmingham Wholesale Market is ablaze BBC News...       1
# 16    @sunkxssedharry will you wear shorts for race ...       0
# 17    #PreviouslyOnDoyinTv: Toke Makinwa泅 marriage ...       0
# 18    Check these out: http://t.co/rOI2NSmEJJ http:/...       0
# 19    PSA: I沸 splitting my personalities.\r\r?? tec...       0
# 20         beware world ablaze sierra leone &amp; guap.       0
# 21    Burning Man Ablaze! by Turban Diva http://t.co...       0
# 22    Not a diss song. People will take 1 thing and ...       0
# 23    Rape victim dies as she sets herself ablaze: A...       1
# 24         SETTING MYSELF ABLAZE http://t.co/6vMe7P5XhC       0
# 25    @CTVToronto the bins in front of the field by ...       0
# 26    #nowplaying Alfons - Ablaze 2015 on Puls Radio...       0
# 27    'Burning Rahm': Let's hope City Hall builds a ...       0
# 28    @PhilippaEilhart @DhuBlath hurt but her eyes a...       0
# 29    Accident cleared in #PaTurnpike on PATP EB bet...       1
# ...                                                 ...     ...
# 3231  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 3232  KUALA LUMPUR (Reuters) - A piece of a wing tha...       1
# 3233  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 3234  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 3235  TOP STORY: wreckage from #MH370 officially con...       1
# 3236  #science Now that a piece of wreckage from fli...       1
# 3237  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 3238  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 3239  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 3240  Wrecked an hour on YouTube with @julian_lage @...       0
# 3241  Israel wrecked my home. Now it wants my land. ...       1
# 3242  'What manner of human being would parcel out a...       0
# 3243  http://t.co/DeQQOpSP4f: Iger's 3 words that wr...       0
# 3244  I just wanna ease your mind and make you feel ...       0
# 3245           coleslaw #wrecked http://t.co/sijNBmCZIJ       0
# 3246  300K exotic car wrecked in train accident \rht...       1
# 3247                      @Tunes_WGG lol. U got wrecked       0
# 3248                         you wrecked my whole world       0
# 3249  @stighefootball Begovic has been garbage. He g...       0
# 3250  Had an awesome time gettin wrecked at bowling ...       0
# 3251  #FX #forex #trading Cramer: Iger's 3 words tha...       0
# 3252  #Sismo DETECTADO #Jap岯n 15:41:07 Seismic inten...       1
# 3253  BREAKING: #ISIS claims responsibility for mosq...       1
# 3254  A gas thing just exploded and I heard screams ...       1
# 3255  a siren just went off and it wasn't the Forney...       1
# 3256  EARTHQUAKE SAFETY LOS ANGELES ?SAFETY FASTENE...       0
# 3257  Officials say a quarantine is in place at an A...       1
# 3258  Storm in RI worse than last hurricane. My city...       1
# 3259  Two giant cranes holding a bridge collapse int...       1
# 3260  Police investigating after an e-bike collided ...       1
#
# [3261 rows x 7 columns]

# %%
subm_df = merged_df[['id', 'target']]
subm_df
# Out:
#          id  target
# 0         0       1
# 1         2       1
# 2         3       1
# 3         9       1
# 4        11       1
# 5        12       1
# 6        21       0
# 7        22       0
# 8        27       0
# 9        29       0
# 10       30       0
# 11       35       0
# 12       42       0
# 13       43       0
# 14       45       0
# 15       46       1
# 16       47       0
# 17       51       0
# 18       58       0
# 19       60       0
# 20       69       0
# 21       70       0
# 22       72       0
# 23       75       1
# 24       84       0
# 25       87       0
# 26       88       0
# 27       90       0
# 28       94       0
# 29       99       1
# ...     ...     ...
# 3231  10740       1
# 3232  10742       1
# 3233  10756       1
# 3234  10757       1
# 3235  10758       1
# 3236  10761       1
# 3237  10762       1
# 3238  10773       1
# 3239  10778       1
# 3240  10781       0
# 3241  10791       1
# 3242  10792       0
# 3243  10796       0
# 3244  10797       0
# 3245  10801       0
# 3246  10804       1
# 3247  10806       0
# 3248  10807       0
# 3249  10816       0
# 3250  10820       0
# 3251  10828       0
# 3252  10836       1
# 3253  10838       1
# 3254  10845       1
# 3255  10856       1
# 3256  10857       0
# 3257  10858       1
# 3258  10861       1
# 3259  10865       1
# 3260  10868       1
#
# [3261 rows x 2 columns]

# %%
subm_df.to_csv('submission.csv', index=False) # The holy grail of a perfect ML model prediction
